# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("D:/LPU/Internship/real data project/US Pathway Complete Data.xlsx",sheet_name="campaign_performance")#Reading the excel file
df
# Out:
#            dates                        campaign_name campaign_start_date  \
# 0     2024-04-29           USP_Search_APTNTSKA_250124                 NaT
# 1     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424                 NaT
# 2     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424                 NaT
# 3     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424                 NaT
# 4     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424                 NaT
# ...          ...                                  ...                 ...
# 28529 2024-03-12        USP_MS + Coop Campaign_240224                 NaT
# 28530 2024-03-12        USP_MS + Coop Campaign_240224                 NaT
# 28531 2024-03-12      USP Study Abroad_Generic_240224                 NaT
# 28532 2024-03-12      USP Study Abroad_Generic_240224                 NaT
# 28533 2024-03-12      USP Study Abroad_Generic_240224                 NaT
#
#                            creative_name  total_spent  impressions  clicks  \
# ...

# %%
df.shape
# Out:
# (28534, 11)

# %%
df.dtypes
# Out:
# dates                  datetime64[ns]
# campaign_name                  object
# campaign_start_date    datetime64[ns]
# creative_name                  object
# total_spent                   float64
# impressions                     int64
# clicks                          int64
# click_through_rate            float64
# leads                         float64
# platform                       object
# adset_name                     object
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# dates                      0
# campaign_name              0
# campaign_start_date    24287
# creative_name              0
# total_spent                0
# impressions                0
# clicks                     0
# click_through_rate        37
# leads                      0
# platform                   0
# adset_name              4247
# dtype: int64

# %%
df.drop(['campaign_start_date'], axis=1, inplace=True)

# %%
df.fillna(df['click_through_rate'].median(),inplace=True)#Using median to fill NA values

# %%
df.fillna({"adset_name":"Unknown"},inplace=True)

# %%
print(df.isnull().sum())
# Out:
# dates                 0
# campaign_name         0
# creative_name         0
# total_spent           0
# impressions           0
# clicks                0
# click_through_rate    0
# leads                 0
# platform              0
# adset_name            0
# dtype: int64

# %%
df.to_excel("D:/LPU/Internship/real data project/updated_camp.xlsx", index=False)#Extracting the cleaned data

# %%
# Summary statistics for total_spent
print("Summary statistics for total_spent:")
print(df['total_spent'].describe())

# Histogram of total_spent
plt.figure(figsize=(10, 6))
df['total_spent'].hist(bins=20)
plt.title('Distribution of Total Spent')
plt.xlabel('Total Spent')
plt.ylabel('Frequency')
plt.show()
# Out:
# Summary statistics for total_spent:
# count    28534.000000
# mean       554.604671
# std       1460.307139
# min          0.000000
# 25%          5.430000
# 50%         53.285000
# 75%        430.692500
# max      27125.360000
# Name: total_spent, dtype: float64

# %%
# Summary statistics for impressions
print("Summary statistics for impressions:")
print(df['impressions'].describe())

# Histogram of impressions
plt.figure(figsize=(10, 6))
df['impressions'].hist(bins=20)
plt.title('Distribution of Impressions')
plt.xlabel('Impressions')
plt.ylabel('Frequency')
plt.show()
# Out:
# Summary statistics for impressions:
# count     28534.000000
# mean       2381.018399
# std        7988.027522
# min           0.000000
# 25%          13.000000
# 50%         107.000000
# 75%        1281.000000
# max      196585.000000
# Name: impressions, dtype: float64

# %%
# Summary statistics for clicks
print("Summary statistics for clicks:")
print(df['clicks'].describe())

# Histogram of clicks
plt.figure(figsize=(10, 6))
df['clicks'].hist(bins=20)
plt.title('Distribution of Clicks')
plt.xlabel('Clicks')
plt.ylabel('Frequency')
plt.show()
# Out:
# Summary statistics for clicks:
# count    28534.000000
# mean        18.770625
# std         78.486205
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          9.000000
# max       3361.000000
# Name: clicks, dtype: float64

# %%
# Summary statistics for click_through_rate
print("Summary statistics for click_through_rate:")
print(df['click_through_rate'].describe())

# Histogram of click_through_rate
plt.figure(figsize=(10, 6))
df['click_through_rate'].hist(bins=20)
plt.title('Distribution of Click Through Rate')
plt.xlabel('Click Through Rate')
plt.ylabel('Frequency')
plt.show()
# Out:
# Summary statistics for click_through_rate:
# count    28534.000000
# mean         1.160566
# std          5.486921
# min          0.000000
# 25%          0.000000
# 50%          0.005800
# 75%          0.656841
# max        200.000000
# Name: click_through_rate, dtype: float64

# %%
# Summary statistics for leads
print("Summary statistics for leads:")
print(df['leads'].describe())

# Histogram of leads
plt.figure(figsize=(10, 6))
df['leads'].hist(bins=20)
plt.title('Distribution of Leads')
plt.xlabel('Leads')
plt.ylabel('Frequency')
plt.show()
# Out:
# Summary statistics for leads:
# count    28534.000000
# mean         1.192799
# std          4.062136
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max        153.000000
# Name: leads, dtype: float64
